# %% [markdown]
# # Download Data

# %%
# !pip install -q kaggle
import json

data = {"username":"tunkedsaro","key":"ff3d00dc680ff94caf6f8d4d9bcd3168"}
json_data = json.dumps(data)

# Write the JSON string to a file
file_path = "/content/kaggle.json"
with open(file_path, 'w') as json_file:
    json_file.write(json_data)

# !mkdir ~/.kaggle
# !cp /content/kaggle.json ~/.kaggle/ #copy api key ---- depend on your directory -- my directory is .../colab/..
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets list
# !kaggle competitions download -c brain-motor-imagery-classification
# !unzip /content/brain-motor-imagery-classification.zip
# Out:
# ref                                                                 title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# rabieelkharoua/students-performance-dataset                         📚 Students Performance Dataset 📚                    66KB  2024-06-12 23:09:20          10801        227  1.0
# nelgiriyewithana/most-streamed-spotify-songs-2024                   Most Streamed Spotify Songs 2024                   496KB  2024-06-15 18:50:51           8385        171  1.0
# dataanalyst001/world-population-by-country-2024                     World Population by country 2024                     6KB  2024-07-04 09:47:58           1148         26  1.0
# ...

# %% [markdown]
# <hr>

# %% [markdown]
# # Observer Data

# %%
import pandas as pd
import numpy as np
import  matplotlib.pyplot as plt

# %%
sample_submission = pd.read_csv("/content/sample_submission.csv")
sample_submission
# Out:
#                                        id  predict
# 0    a0dfb1f6-a76b-404f-a04a-b61e955ce1ef    110.0
# 1    51afd110-7556-4a7d-b6d2-68e46256f267    150.0
# 2    eb229854-1a14-4e1f-8e52-470edbec47c9    150.0
# 3    8fa74efe-f269-415e-a968-1a92e7c66fe6      NaN
# 4    7b209881-a1dd-4aa3-a06a-037908b07bfa      NaN
# ..                                    ...      ...
# 475  69e84db3-0019-4e38-90fc-968f45747a16      NaN
# 476  d18d7d80-78fa-402a-ba1c-e35d72382b18      NaN
# 477  0a532391-dd42-413f-ab15-798960de95d6      NaN
# 478  0c02ad4f-de15-48cb-ad31-0925e69bfe97      NaN
# 479  dfe24504-2ec8-4170-bc86-f3f127bf0e8f      NaN
#
# [480 rows x 2 columns]

# %%
data = np.load('/content/train/train/s1_d2_p002_002_data_time_series.npy')
data
# Out:
# array([[-1.5024611e+05, -1.3947131e+05, -1.6976562e+05, ...,
#          9.3333344e+01,  2.3388000e+04,  1.0000000e+00],
#        [-1.5028661e+05, -1.3956180e+05, -1.6974086e+05, ...,
#          9.3333344e+01,  2.3389000e+04,  1.0000000e+00],
#        [-1.4997638e+05, -1.3916098e+05, -1.6970420e+05, ...,
#          9.3333344e+01,  2.3390000e+04,  1.0000000e+00],
#        ...,
#        [-1.5547311e+05, -1.4366539e+05, -1.7719748e+05, ...,
#          9.3333344e+01,  7.7099000e+04,  1.0000000e+00],
#        [-1.5553006e+05, -1.4377259e+05, -1.7717298e+05, ...,
#          9.3333344e+01,  7.7100000e+04,  1.0000000e+00],
#        [-1.5525612e+05, -1.4341470e+05, -1.7714178e+05, ...,
#          9.3333344e+01,  7.7101000e+04,  1.0000000e+00]], dtype=float32)

# %%
df = pd.DataFrame(data)
df
# Out:
#                   0              1              2              3   \
# 0     -150246.109375 -139471.312500 -169765.625000 -154886.687500
# 1     -150286.609375 -139561.796875 -169740.859375 -154901.343750
# 2     -149976.375000 -139160.984375 -169704.203125 -154696.609375
# 3     -149873.015625 -138968.937500 -169728.062500 -154640.187500
# 4     -150035.109375 -139166.796875 -169765.000000 -154757.765625
# ...              ...            ...            ...            ...
# 53709 -155142.031250 -143221.218750 -177161.187500 -159815.875000
# 53710 -155283.562500 -143390.203125 -177193.906250 -159913.062500
# 53711 -155473.109375 -143665.390625 -177197.484375 -160029.203125
# 53712 -155530.062500 -143772.593750 -177172.984375 -160056.015625
# 53713 -155256.125000 -143414.703125 -177141.781250 -159881.671875
#
#                  4            5             6             7         8   \
# 0     -34824.109375  4304.052246 -18094.900391  85135.562500 -0.020508
# ...

# %%
data.shape
# Out:
# (53714, 17)

# %%
label = np.load("/content/train/train/s1_d2_p002_002_data_time_stamps.npy")
print(label)
# Out:
# [61679.01362649 61679.01764724 61679.02166798 ... 61894.97194118
#  61894.97596193 61894.97998268]

# %%
label
# Out:
# array([61679.01362649, 61679.01764724, 61679.02166798, ...,
#        61894.97194118, 61894.97596193, 61894.97998268])

# %%
signals = np.load('/content/train/train/s1_d2_p002_002_data_time_series.npy')
times   = np.load('/content/train/train/s1_d2_p002_002_data_time_stamps.npy')

# %%
signals.shape
# Out:
# (53714, 17)

# %%
times.shape
# Out:
# (53714,)

# %%
# Number of channels
num_channels = signals.shape[1]

# Create a plot for each channel
plt.figure(figsize=(20, 10))
for i in range(num_channels):
    plt.subplot(num_channels, 1, i + 1)  # Create a subplot for each channel
    plt.plot(times, signals[:, i])
    plt.title(f'Channel {i + 1}')
    plt.xlabel('Time')
    plt.grid(alpha=0.4)
    # plt.ylabel('Amplitude')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-b9c179e20055>:14: UserWarning: Tight layout not applied. tight_layout cannot make axes height small enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
label_time_series = np.load('/content/train/train/s1_d2_p002_002_label_time_series.npy')
label_time_stamps = np.load('/content/train/train/s1_d2_p002_002_label_time_stamps.npy')

# %%
print(label_time_series.shape)
label_time_series
# Out:
# (30, 1)
# array([[120],
#        [110],
#        [150],
#        [150],
#        [120],
#        [110],
#        [120],
#        [110],
#        [150],
#        [150],
#        [120],
#        [110],
#        [120],
#        [150],
#        [110],
#        [150],
#        [120],
#        [110],
#        [120],
#        [110],
#        [150],
#        [150],
#        [120],
#        [110],
#        [150],
#        [120],
#        [110],
#        [150],
#        [120],
#        [110]], dtype=int32)

# %%
print(label_time_stamps.shape)
label_time_stamps
# Out:
# (30,)
# array([61686.01314177, 61693.0120196 , 61700.01039654, 61707.01147227,
#        61714.00906591, 61721.00822104, 61728.00744448, 61735.01338961,
#        61742.00668995, 61749.01066038, 61756.00574462, 61763.00786315,
#        61770.00543239, 61777.00504162, 61784.00421806, 61791.00980019,
#        61798.00777393, 61805.00275706, 61812.0041517 , 61819.00191293,
#        61826.00334947, 61833.001456  , 61840.00028594, 61846.99985067,
#        61854.00596491, 61860.99933954, 61867.99867558, 61874.99838351,
#        61881.99778285, 61888.99908488])

# %%
plt.plot(label_time_stamps, label_time_series)
plt.grid(alpha=0.4)

# %% [markdown]
# # Data visualize

# %%
import numpy as np
import matplotlib.pyplot as plt

# Assume these arrays are already loaded
signals = np.load('/content/train/train/s1_d2_p002_002_data_time_series.npy')
times = np.load("/content/train/train/s1_d2_p002_002_data_time_stamps.npy")
label_time_series = np.load('/content/train/train/s1_d2_p002_002_label_time_series.npy')
label_time_stamps = np.load('/content/train/train/s1_d2_p002_002_label_time_stamps.npy')

# Data for plotting
signal01 = signals[:,10]
times01 = times
label_time_series01 = label_time_series
label_time_stamps01 = label_time_stamps

# Create the plot
plt.figure(figsize=(15, 5))
plt.plot(times01, signal01, label='Channel 1 Signal')

# Plot the labels
for i, label in enumerate(label_time_series01):
    # Find the nearest index in times01 that matches the label_time_stamps01
    idx = np.abs(times01 - label_time_stamps01[i]).argmin()
    plt.axvline(x=times01[idx], color='r', linestyle='--')
    plt.text(times01[idx], signal01[idx], f'{label[0]}', fontsize=12, verticalalignment='bottom')

plt.title('Signal of Channel 1 Over Time with Labels')
plt.xlabel('Time')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the data
signals = np.load('/content/train/train/s1_d2_p002_002_data_time_series.npy')
times = np.load("/content/train/train/s1_d2_p002_002_data_time_stamps.npy")
label_time_series = np.load('/content/train/train/s1_d2_p002_002_label_time_series.npy')
label_time_stamps = np.load('/content/train/train/s1_d2_p002_002_label_time_stamps.npy')

# Number of channels
num_channels = signals.shape[1]

# Create a plot
plt.figure(figsize=(20, 30))

for i in range(num_channels):
    plt.subplot(num_channels, 1, i + 1)
    plt.plot(times, signals[:, i], label=f'Channel {i + 1} Signal')

    # Plot the labels
    for j, label in enumerate(label_time_series):
        idx = np.abs(times - label_time_stamps[j]).argmin()
        plt.axvline(x=times[idx], color='r', linestyle='--')
        plt.text(times[idx], signals[idx, i], f'{label[0]}', fontsize=8, verticalalignment='bottom')

    plt.title(f'Channel {i + 1} Signal')
    plt.xlabel('Time')
    plt.ylabel('Amplitude')
    plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# <hr>

# %%
from scipy.signal import butter, filtfilt, iirnotch, freqz
import os
import numpy as np

# %%
# Band-pass filter
def bandpass_filter(data, lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    y = filtfilt(b, a, data)
    return y

# %%
# Notch filter
def notch_filter(data, cut_freq, fs, Q=30):
    nyq = 0.5 * fs
    freq = cut_freq / nyq
    b, a = iirnotch(freq, Q)
    y = filtfilt(b, a, data)
    return y

# %%
def filter03050(Ipsignal):
    sampling_rate = 250  # Hz
    # fft_signal = np.fft.fft(Ipsignal)
    # frequencies = np.fft.fftfreq(len(Ipsignal), 1/sampling_rate)
    filtered_signal = bandpass_filter(Ipsignal, 1, 30, sampling_rate)          # band-pass filter 0-30 Hz
    filtered_signal = notch_filter(filtered_signal, 50, sampling_rate)       # notch filter 50 Hz
    return filtered_signal

# %%
def unique_name(Datapath):
    all_name = os.listdir(Datapath)
    new = []
    for un in all_name:
        i = un.replace("_data_time_series.npy","").replace("_data_time_stamps.npy","").replace("_label_time_series.npy","").replace("_label_time_stamps.npy","")
        new.append(i)
        unique_name = list(set(new))
    return unique_name

# %%
file_path = "/content/train/train"
file_path
# Out:
# '/content/train/train'

# %%
unique_name = unique_name(file_path)
unique_name
# Out:
# ['s2_d3_p013_007',
#  's1_d2_p008_003',
#  's1_d2_p008_002',
#  's1_d2_p005_006',
#  's2_d3_p016_007',
#  's1_d2_p010_007',
#  's2_d3_p017_004',
#  's1_d2_p010_003',
#  's2_d2_p003_007',
#  's2_d2_p002_005',
#  's2_d2_p007_002',
#  's2_d2_p006_003',
#  's2_d2_p010_006',
#  's2_d3_p017_003',
#  's2_d3_p016_006',
#  's1_d3_p014_008',
#  's2_d3_p015_008',
#  's2_d3_p016_008',
#  's1_d2_p004_006',
#  's2_d2_p009_006',
#  's2_d2_p011_004',
#  's1_d2_p010_004',
#  's1_d2_p006_007',
#  's2_d3_p013_002',
#  's1_d2_p008_005',
#  's1_d2_p009_004',
#  's1_d3_p013_008',
#  's2_d3_p019_008',
#  's2_d2_p007_001',
#  's2_d2_p002_007',
#  's2_d2_p008_004',
#  's1_d3_p019_001',
#  's1_d2_p010_006',
#  's1_d2_p004_002',
#  's2_d2_p009_008',
#  's1_d3_p019_008',
#  's1_d2_p005_003',
#  's2_d2_p010_005',
#  's1_d2_p002_002',
#  's2_d3_p015_005',
#  's2_d3_p017_001',
#  's2_d3_p016_005',
#  's2_d2_p007_008',
#  's2_d3_p014_005',
#  's2_d2_p006_004',
#  's2_d3_p016_002',
#  's1_d3_p016_006',
# ...

# %%
unique_name.remove("s1_d2_p002_003")
unique_name.remove("s1_d2_p006_008")
unique_name.remove("s2_d2_p002_006")

# %% [markdown]
# <hr>

# %%
data_dataset  = []
label_dataset = []
for name in unique_name:
    # print(name)
    signals           = np.load(os.path.join(file_path,name+"_data_time_series.npy"))
    times             = np.load(os.path.join(file_path,name+"_data_time_stamps.npy"))
    label_time_series = np.load(os.path.join(file_path,name+"_label_time_series.npy"))
    label_time_stamps = np.load(os.path.join(file_path,name+"_label_time_stamps.npy"))
    signals = signals[:,:8]
    if filter!=None:
        filtered_signal = []
        Dim = signals.shape[1]
        # print(Dim)
        for i in range(Dim):
            # print(f"{i} : {signals[:,i]}")
            filtered_signal.append(filter03050(signals[:,i]))
        signals = np.array(filtered_signal).T
    datapoint = 250 * 7                   # 250 Hz * 7 s
    for index in range(30):
        # start_point = index * datapoint
        # end_point = (index + 1) * datapoint
        # if end_point <= signals.shape[0]:  # Check to ensure slice is within the data range
        #     data_dataset.append(signals[start_point:end_point])
        # else:
        #     break
        sn = signals[1750*i:1750*(i+1)]
        if sn.shape[0]!=30 and sn.shape[1]!=8:
            print(name,"error")
        data_dataset.append(sn)
    label_dataset.append(label_time_series)
    break

data_dataset = np.stack(data_dataset)

label_dataset = np.concatenate(label_dataset)
label_dataset = label_dataset.flatten().tolist()
# print(data_dataset)
# print(label_dataset)
data_sliced_with_label = tuple(zip(data_dataset,label_dataset))
# Out:
# s2_d3_p013_007 error
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-73d2b3e62346> in <cell line: 1>()
#      18         if sn.shape[0] != 30 or sn.shape[1] != 8:
#      19             print(name, "error")
# ---> 20         data_dataset.append(sn)
#      21
#      22     label_dataset.append(label_time_series)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
data_dataset  = []
label_dataset = []
for name in unique_name:
    signals = np.load(os.path.join(file_path, name + "_data_time_series.npy"))
    times = np.load(os.path.join(file_path, name + "_data_time_stamps.npy"))
    label_time_series = np.load(os.path.join(file_path, name + "_label_time_series.npy"))
    label_time_stamps = np.load(os.path.join(file_path, name + "_label_time_stamps.npy"))
    signals = signals[:, :8]

    if filter is not None:
        filtered_signal = []
        Dim = signals.shape[1]
        for i in range(Dim):
            filtered_signal.append(filter03050(signals[:, i]))
        signals = np.array(filtered_signal).T

# %%
signals = np.load(os.path.join(file_path, name + "_data_time_series.npy"))[:,:5]
times = np.load(os.path.join(file_path, name + "_data_time_stamps.npy"))
label_time_series = np.load(os.path.join(file_path, name + "_label_time_series.npy"))
label_time_stamps = np.load(os.path.join(file_path, name + "_label_time_stamps.npy"))

# %%
signals = pd.DataFrame(signals)
signals
# Out:
#                    0              1              2              3  \
# 0     -198000.875000 -201827.140625 -191777.171875 -213303.421875
# 1     -198050.859375 -201866.390625 -191858.984375 -213348.937500
# 2     -198130.250000 -201932.203125 -192010.343750 -213445.765625
# 3     -198167.171875 -201963.406250 -192088.125000 -213502.703125
# 4     -198062.750000 -201878.812500 -191901.531250 -213390.500000
# ...              ...            ...            ...            ...
# 56695 -200291.046875 -203863.656250 -193489.140625 -215722.156250
# 56696 -200277.812500 -203844.875000 -193442.828125 -215681.921875
# 56697 -200341.906250 -203895.843750 -193558.968750 -215751.390625
# 56698 -200430.062500 -203969.515625 -193725.890625 -215861.000000
# 56699 -200418.890625 -203960.656250 -193719.531250 -215869.406250
#
#                    4
# 0     -134402.562500
# 1     -134455.312500
# 2     -134545.078125
# 3     -134588.000000
# 4     -134474.890625
# ...              ...
# ...

# %%
time = pd.DataFrame(times)  # 250*7 = 1750
time.rename(columns={0: 'time'}, inplace=True)
time
# Out:
#               time
# 0      1324.373366
# 1      1324.377359
# 2      1324.381352
# 3      1324.385345
# 4      1324.389338
# ...            ...
# 56695  1550.764323
# 56696  1550.768316
# 56697  1550.772309
# 56698  1550.776302
# 56699  1550.780295
#
# [56700 rows x 1 columns]

# %%
label_val = pd.DataFrame(np.load(os.path.join(file_path, name + "_label_time_series.npy")))
label_val.rename(columns={0: 'label_value'}, inplace=True)
label_val
# Out:
#     label_value
# 0           120
# 1           110
# 2           150
# 3           150
# 4           120
# 5           110
# 6           120
# 7           110
# 8           150
# 9           150
# 10          120
# 11          110
# 12          120
# 13          150
# 14          110
# 15          150
# 16          120
# 17          110
# 18          120
# 19          110
# 20          150
# 21          150
# 22          120
# 23          110
# 24          150
# 25          120
# 26          110
# 27          150
# 28          120
# 29          110

# %%
label_time = pd.DataFrame(label_time_stamps)
label_time.rename(columns={0: 'label_time'}, inplace=True)
label_time
# Out:
#      label_time
# 0   1335.060271
# 1   1342.074825
# 2   1349.074111
# 3   1356.074978
# 4   1363.073204
# 5   1370.080354
# 6   1377.072717
# 7   1384.077834
# 8   1391.072547
# 9   1398.071923
# 10  1405.071645
# 11  1412.077552
# 12  1419.071189
# 13  1426.075670
# 14  1433.071122
# 15  1440.070579
# 16  1447.070015
# 17  1454.075399
# 18  1461.069559
# 19  1468.069176
# 20  1475.068621
# 21  1482.075278
# 22  1489.068292
# 23  1496.073201
# 24  1503.067972
# 25  1510.067270
# 26  1517.067114
# 27  1524.073423
# 28  1531.067367
# 29  1538.066580

# %%
stamp = pd.concat([label_time,label_val],axis=1)
stamp
# Out:
#      label_time  label_value
# 0   1335.060271          120
# 1   1342.074825          110
# 2   1349.074111          150
# 3   1356.074978          150
# 4   1363.073204          120
# 5   1370.080354          110
# 6   1377.072717          120
# 7   1384.077834          110
# 8   1391.072547          150
# 9   1398.071923          150
# 10  1405.071645          120
# 11  1412.077552          110
# 12  1419.071189          120
# 13  1426.075670          150
# 14  1433.071122          110
# 15  1440.070579          150
# 16  1447.070015          120
# 17  1454.075399          110
# 18  1461.069559          120
# 19  1468.069176          110
# 20  1475.068621          150
# 21  1482.075278          150
# 22  1489.068292          120
# 23  1496.073201          110
# 24  1503.067972          150
# 25  1510.067270          120
# 26  1517.067114          110
# 27  1524.073423          150
# 28  1531.067367          120
# 29  1538.066580          110

# %%
combined_df = pd.concat([signals, time], axis=1)
combined_df
# Out:
#                    0              1              2              3  \
# 0     -198000.875000 -201827.140625 -191777.171875 -213303.421875
# 1     -198050.859375 -201866.390625 -191858.984375 -213348.937500
# 2     -198130.250000 -201932.203125 -192010.343750 -213445.765625
# 3     -198167.171875 -201963.406250 -192088.125000 -213502.703125
# 4     -198062.750000 -201878.812500 -191901.531250 -213390.500000
# ...              ...            ...            ...            ...
# 56695 -200291.046875 -203863.656250 -193489.140625 -215722.156250
# 56696 -200277.812500 -203844.875000 -193442.828125 -215681.921875
# 56697 -200341.906250 -203895.843750 -193558.968750 -215751.390625
# 56698 -200430.062500 -203969.515625 -193725.890625 -215861.000000
# 56699 -200418.890625 -203960.656250 -193719.531250 -215869.406250
#
#                    4         time
# 0     -134402.562500  1324.373366
# 1     -134455.312500  1324.377359
# 2     -134545.078125  1324.381352
# ...

# %%
def find_closest_label_time(time, label_times):
    closest_time = min(label_times, key=lambda x: abs(x - time))
    return closest_time

# %%
combined_df['closest_label_time'] = combined_df['time'].apply(lambda x: find_closest_label_time(x, stamp['label_time']))
combined_df
# Out:
#                    0              1              2              3  \
# 0     -198000.875000 -201827.140625 -191777.171875 -213303.421875
# 1     -198050.859375 -201866.390625 -191858.984375 -213348.937500
# 2     -198130.250000 -201932.203125 -192010.343750 -213445.765625
# 3     -198167.171875 -201963.406250 -192088.125000 -213502.703125
# 4     -198062.750000 -201878.812500 -191901.531250 -213390.500000
# ...              ...            ...            ...            ...
# 56695 -200291.046875 -203863.656250 -193489.140625 -215722.156250
# 56696 -200277.812500 -203844.875000 -193442.828125 -215681.921875
# 56697 -200341.906250 -203895.843750 -193558.968750 -215751.390625
# 56698 -200430.062500 -203969.515625 -193725.890625 -215861.000000
# 56699 -200418.890625 -203960.656250 -193719.531250 -215869.406250
#
#                    4         time  closest_label_time
# 0     -134402.562500  1324.373366         1335.060271
# 1     -134455.312500  1324.377359         1335.060271
# ...

# %%
# Merge combined_df with label_df based on 'closest_label_time' and 'label_time'
merged_df = pd.merge(combined_df, stamp, left_on='closest_label_time', right_on='label_time', how='left')
merged_df
# Out:
#                    0              1              2              3  \
# 0     -198000.875000 -201827.140625 -191777.171875 -213303.421875
# 1     -198050.859375 -201866.390625 -191858.984375 -213348.937500
# 2     -198130.250000 -201932.203125 -192010.343750 -213445.765625
# 3     -198167.171875 -201963.406250 -192088.125000 -213502.703125
# 4     -198062.750000 -201878.812500 -191901.531250 -213390.500000
# ...              ...            ...            ...            ...
# 56695 -200291.046875 -203863.656250 -193489.140625 -215722.156250
# 56696 -200277.812500 -203844.875000 -193442.828125 -215681.921875
# 56697 -200341.906250 -203895.843750 -193558.968750 -215751.390625
# 56698 -200430.062500 -203969.515625 -193725.890625 -215861.000000
# 56699 -200418.890625 -203960.656250 -193719.531250 -215869.406250
#
#                    4         time  closest_label_time   label_time  \
# 0     -134402.562500  1324.373366         1335.060271  1335.060271
# ...

# %%
# Drop the 'closest_label_time' and 'label_time' columns if not needed
merged_df.drop(columns=['closest_label_time', 'label_time'], inplace=True)

merged_df
# Out:
#                    0              1              2              3  \
# 0     -198000.875000 -201827.140625 -191777.171875 -213303.421875
# 1     -198050.859375 -201866.390625 -191858.984375 -213348.937500
# 2     -198130.250000 -201932.203125 -192010.343750 -213445.765625
# 3     -198167.171875 -201963.406250 -192088.125000 -213502.703125
# 4     -198062.750000 -201878.812500 -191901.531250 -213390.500000
# ...              ...            ...            ...            ...
# 56695 -200291.046875 -203863.656250 -193489.140625 -215722.156250
# 56696 -200277.812500 -203844.875000 -193442.828125 -215681.921875
# 56697 -200341.906250 -203895.843750 -193558.968750 -215751.390625
# 56698 -200430.062500 -203969.515625 -193725.890625 -215861.000000
# 56699 -200418.890625 -203960.656250 -193719.531250 -215869.406250
#
#                    4         time  label_value
# 0     -134402.562500  1324.373366          120
# 1     -134455.312500  1324.377359          120
# ...

# %%
grouped_df = merged_df.groupby('label_value').mean()
grouped_df
# Out:
#                          0              1              2              3  \
# label_value
# 110         -199561.828125 -203203.953125 -193075.046875 -214968.203125
# 120         -199273.937500 -202951.718750 -192868.609375 -214662.953125
# 150         -199424.109375 -203097.796875 -192995.687500 -214825.343750
#
#                          4         time
# label_value
# 110         -135817.000000  1453.646057
# 120         -135550.140625  1423.901955
# 150         -135676.015625  1434.470329
